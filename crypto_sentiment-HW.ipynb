# %%
import os
import pandas as pd
# %matplotlib inline
import nltk
from newsapi import NewsApiClient
nltk.download('punkt')
nltk.download('wordnet')
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\keron\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\keron\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download("stopwords")
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\keron\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
# Create a newsapi client
api_key = os.getenv("NEWS_API_KEY")
newsapi = NewsApiClient(api_key=api_key)

# %%
type(api_key)
# Out:
# str

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(q="bitcoin", language="en")
bitcoin_headlines["articles"][0]
# Out:
# {'source': {'id': 'mashable', 'name': 'Mashable'},
#  'author': 'Stan Schroeder',
#  'title': 'Bitcoin whale moves $1.1 billion in bitcoins for an $80 fee',
#  'description': "Bitcoin hasn't (yet) fulfilled its original promise of being widely-used electronic cash, but it still offers some features that would be hard to achieve within the traditional banking system. Namely, moving $1.1 billion from one address to another, in a sing…",
#  'url': 'https://mashable.com/article/bitcoin-1-1-billion-transaction/',
#  'urlToImage': 'https://mondrian.mashable.com/2020%252F01%252F15%252F38%252Fd26e834787934c56a33fdeb39faa0be8.84e34.jpg%252F1200x630.jpg?signature=IHj6xz7nTFxvmjn6XOvUiHKJCIM=',
#  'publishedAt': '2020-01-15T09:10:59Z',
#  'content': "Bitcoin hasn't (yet) fulfilled its original promise of being widely-used electronic cash, but it still offers some features that would be hard to achieve within the traditional banking system. Namely, moving $1.1 billion from one address to another, in a sing… [+1589 chars]"}

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(q="ethereum", language="en")
ethereum_headlines["articles"][0]
# Out:
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#  'author': 'Josh Constine',
#  'title': 'The crypto rich find security in Anchorage',
#  'description': 'Not the city, the $57 million-funded cryptocurrency custodian startup. When someone wants to keep tens or hundreds of millions of dollars in Bitcoin, Ethereum, or other coins safe, they put them in Anchorage’s vault. And now they can trade straight from custo…',
#  'url': 'http://techcrunch.com/2020/01/15/anchorage-trading-from-custody/',
#  'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/01/Anchorage-Trading-1.png?w=740',
#  'publishedAt': '2020-01-15T11:57:30Z',
#  'content': 'Not the city, the $57 million-funded cryptocurrency custodian startup. When someone wants to keep tens or hundreds of millions of dollars in Bitcoin, Ethereum, or other coins safe, they put them in Anchorage’s vault. And now they can trade straight from custo… [+3802 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-01-15  Bitcoin hasn't (yet) fulfilled its original pr...    0.0088
# 1  2020-01-15  Not the city, the $57 million-funded cryptocur...    0.5859
# 2  2020-01-07  Shutterstock\r\n<ul><li>Bitcoin bulls like to ...    0.6369
# 3  2020-01-29  Bust out the champagne, folks! It's time to ce...   -0.2396
# 4  2020-01-06  Our robot colleague Satoshi Nakaboto writes ab...    0.5070
#
#    positive  negative  neutral
# 0     0.074     0.073    0.853
# 1     0.103     0.000    0.897
# 2     0.198     0.107    0.696
# 3     0.182     0.170    0.648
# 4     0.068     0.000    0.932

# %%
# Create the ethereum sentiment scores DataFrame
ethereum_sentiment = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-01-15  Not the city, the $57 million-funded cryptocur...    0.5859
# 1  2020-01-28  Last week, I took out a loan without meeting a...    0.5719
# 2  2020-01-11  Blockchain has the two most popular and compet...    0.6195
# 3  2020-01-29  Bust out the champagne, folks! It's time to ce...   -0.2396
# 4  2020-01-09  Virgil Griffith, the Ethereum developer arrest...   -0.7096
#
#    positive  negative  neutral
# 0     0.103     0.000    0.897
# 1     0.099     0.000    0.901
# 2     0.112     0.000    0.888
# 3     0.182     0.170    0.648
# 4     0.053     0.182    0.766

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   positive   negative   neutral
# count  20.000000  20.000000  20.000000  20.00000
# mean    0.496245   0.093300   0.017500   0.88925
# std     0.237633   0.047603   0.045626   0.08334
# min    -0.239600   0.067000   0.000000   0.64800
# 25%     0.507000   0.067750   0.000000   0.88850
# 50%     0.507000   0.069000   0.000000   0.93100
# 75%     0.553000   0.081250   0.000000   0.93225
# max     0.907600   0.209000   0.170000   0.93300

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  80.000000  80.000000  80.000000  80.000000
# mean   -0.001560   0.071050   0.068800   0.860300
# std     0.482560   0.055741   0.073878   0.099482
# min    -0.765000   0.000000   0.000000   0.648000
# 25%    -0.391725   0.031500   0.000000   0.799750
# 50%     0.000000   0.065500   0.057000   0.880500
# 75%     0.467575   0.100000   0.139250   0.934500
# max     0.670500   0.189000   0.185000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum has the highest mean score.
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum has the highest compound score.
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum has the highest positive score.

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
import nltk
wnl = WordNetLemmatizer() 
stop = stopwords.words('english')
stop.append("u")
stop.append("it'")
stop.append("'s")
stop.append("n't")
stop.append('…')
stop.append("\`")
stop.append('``')
stop.append('char')
stop.append("''")
stop = set(stop)

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)
    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    # Remove the punctuation
    words = list(filter(lambda t: t not in punctuation, words))
    # Remove the stop words
    words = list(filter(lambda t: t.lower() not in stop, words))
    # Lemmatize Words into root words
    tokens = [wnl.lemmatize(word) for word in words]
    return tokens


# Create a new tokens column for bitcoin
bitcoin_df["tokens"] = bitcoin_df.text.apply(tokenizer)
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-01-15  Bitcoin hasn't (yet) fulfilled its original pr...    0.0088
# 1  2020-01-15  Not the city, the $57 million-funded cryptocur...    0.5859
# 2  2020-01-07  Shutterstock\r\n<ul><li>Bitcoin bulls like to ...    0.6369
# 3  2020-01-29  Bust out the champagne, folks! It's time to ce...   -0.2396
# 4  2020-01-06  Our robot colleague Satoshi Nakaboto writes ab...    0.5070
#
#    positive  negative  neutral  \
# 0     0.074     0.073    0.853
# 1     0.103     0.000    0.897
# 2     0.198     0.107    0.696
# 3     0.182     0.170    0.648
# 4     0.068     0.000    0.932
#
#                                               tokens
# 0  [Bitcoin, yet, fulfilled, original, promise, w...
# 1  [city, 57, million-funded, cryptocurrency, cus...
# 2  [Shutterstock, ul, li, Bitcoin, bull, like, cl...
# 3  [Bust, champagne, folk, time, celebrate, 2019,...
# 4  [robot, colleague, Satoshi, Nakaboto, writes, ...

# %%
# Create a new tokens column for ethereum
ethereum_df["tokens"] = ethereum_df.text.apply(tokenizer)
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-01-15  Not the city, the $57 million-funded cryptocur...    0.5859
# 1  2020-01-28  Last week, I took out a loan without meeting a...    0.5719
# 2  2020-01-11  Blockchain has the two most popular and compet...    0.6195
# 3  2020-01-29  Bust out the champagne, folks! It's time to ce...   -0.2396
# 4  2020-01-09  Virgil Griffith, the Ethereum developer arrest...   -0.7096
#
#    positive  negative  neutral  \
# 0     0.103     0.000    0.897
# 1     0.099     0.000    0.901
# 2     0.112     0.000    0.888
# 3     0.182     0.170    0.648
# 4     0.053     0.182    0.766
#
#                                               tokens
# 0  [city, 57, million-funded, cryptocurrency, cus...
# 1  [Last, week, took, loan, without, meeting, any...
# 2  [Blockchain, two, popular, competitive, platfo...
# 3  [Bust, champagne, folk, time, celebrate, 2019,...
# 4  [Virgil, Griffith, Ethereum, developer, arrest...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
N = 2
grams = ngrams(tokenizer(bitcoin_df.text.str.cat()), N)
Counter(grams).most_common(20)
# Out:
# [(('Satoshi', 'Nakaboto'), 32),
#  (('char', 'robot'), 16),
#  (('robot', 'colleague'), 16),
#  (('colleague', 'Satoshi'), 16),
#  (('Nakaboto', 'writes'), 16),
#  (('writes', 'Bitcoin'), 16),
#  (('every', 'fucking'), 16),
#  (('fucking', 'day'), 16),
#  (('day', 'Welcome'), 16),
#  (('Welcome', 'another'), 16),
#  (('another', 'edition'), 16),
#  (('edition', 'Bitcoin'), 16),
#  (('Bitcoin', 'Today'), 16),
#  (('Today', 'Satoshi'), 16),
#  (('Nakaboto', 'tell'), 16),
#  (('tell', 'whats'), 16),
#  (('whats', 'going'), 16),
#  (('going', 'Bitcoin'), 16),
#  (('Bitcoin', 'past'), 16),
#  (('past', '24'), 16)]

# %%
# Generate the Ethereum N-grams where N=2
N = 2
grams = ngrams(tokenizer(ethereum_df.text.str.cat()), N)
Counter(grams).most_common(20)
# Out:
# [(('Bitcoin', 'Ethereum'), 8),
#  (('North', 'Korea'), 8),
#  (('cryptocurrency', 'conference'), 8),
#  (('cryptocurrency', 'blockchain'), 8),
#  (('char', 'Dfinity'), 8),
#  (('Bitcoin', 'mine'), 8),
#  (('blockchain', 'police'), 8),
#  (('police', 'bodycam'), 8),
#  (('city', '57'), 4),
#  (('57', 'million-funded'), 4),
#  (('million-funded', 'cryptocurrency'), 4),
#  (('cryptocurrency', 'custodian'), 4),
#  (('custodian', 'startup'), 4),
#  (('startup', 'someone'), 4),
#  (('someone', 'want'), 4),
#  (('want', 'keep'), 4),
#  (('keep', 'ten'), 4),
#  (('ten', 'hundred'), 4),
#  (('hundred', 'million'), 4),
#  (('million', 'dollar'), 4)]

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
all_tokens = tokenizer(bitcoin_df.text.str.cat())
token_count(all_tokens, 10)
# Out:
# [('Bitcoin', 51),
#  ('Satoshi', 34),
#  ('Nakaboto', 32),
#  ('char', 20),
#  ('another', 17),
#  ('say', 17),
#  ('robot', 16),
#  ('colleague', 16),
#  ('writes', 16),
#  ('every', 16)]

# %%
# Get the top 10 words for Ethereum
all_tokens = tokenizer(ethereum_df.text.str.cat())
token_count(all_tokens, 10)
# Out:
# [('char', 80),
#  ('cryptocurrency', 60),
#  ('blockchain', 40),
#  ('Bitcoin', 28),
#  ('’', 20),
#  ('even', 20),
#  ('Ethereum', 16),
#  ('also', 16),
#  ('asset', 16),
#  ('platform', 16)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
def wordcloud(text, title=""):
    df_cloud = WordCloud(width=500, colormap='RdYlBu').generate(text)
    plt.imshow(df_cloud)
    plt.axis("off")
    fontdict = {"fontsize": 48, "fontweight" : "bold"}
    plt.title(title, fontdict=fontdict)
    plt.show()
    
wordcloud(bitcoin_df.text.str.cat(), title="Bitcoin Word Cloud")

# %%
# Generate the Ethereum word cloud
wordcloud(ethereum_df.text.str.cat(), title="Ethereum Word Cloud")

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Optional - download a language model for SpaCy
#!python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
bitcoin_text = bitcoin_df.text.str.cat()
bitcoin_text
# Out:
# 'Bitcoin hasn\'t (yet) fulfilled its original promise of being widely-used electronic cash, but it still offers some features that would be hard to achieve within the traditional banking system. Namely, moving $1.1 billion from one address to another, in a sing… [+1589 chars]Not the city, the $57 million-funded cryptocurrency custodian startup. When someone wants to keep tens or hundreds of millions of dollars in Bitcoin, Ethereum, or other coins safe, they put them in Anchorage’s vault. And now they can trade straight from custo… [+3802 chars]Shutterstock\r\n<ul><li>Bitcoin bulls like to claim that bitcoin is a great haven investment, like gold, in times of geopolitical uncertainty. </li><li>"These people ignore all the times that it moves inversely with sentiment," says Oanda\'s Craig Erlam.</li><li… [+2002 chars]Bust out the champagne, folks! It\'s time to celebrate.\xa0\r\n2019 was one hell of a year for cryptocurrency. Or, more specifically, cryptocurrency scams. That\'s according to Chainalysis, a respected blockchain analysis company that works with law enforcement and … [+2253 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Satoshi Nakamoto used to say: Were on the … [+2502 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Marie Curie used to say: Lets get it!\r\nBit… [+2657 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Pasteur used to say: Live, laugh, love!\r\nB… [+2844 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Success is ju… [+2651 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Isaac Newton used to say: Lets get it!… [+2347 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Marcus Aurelius used to say: Were\xa0on t… [+2584 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Live, lau… [+2589 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Shleppppppp i… [+2530 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Faraday used to say: Were\xa0on the highw… [+2787 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Nikola Tesla used to say: Intelligence… [+2546 chars]Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin  ...

# %%
# Run the NER processor on all of the text
bitcoin_doc = nlp(bitcoin_text)
# Add a title to the document
bitcoin_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_doc, style='ent', jupyter=True)
# Out:
# <h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  hasn't (yet) fulfilled its original promise of being widely-used electronic cash, but it still offers some features that would be hard to achieve within the traditional banking system. Namely, moving
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  from one address to another, in a sing… [+1589 chars]Not the city, the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $57 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# -funded cryptocurrency custodian startup. When someone wants to keep
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tens or hundreds of millions of dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Ethereum, or other coins safe, they put them in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anchorage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s vault. And now they can trade straight from custo… [
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +3802 chars]Shutterstock
# &lt;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ul&gt;&lt;li&gt;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  bulls like to claim that
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is a great haven investment, like gold, in times of geopolitical uncertainty. &lt;/li&gt;&lt;li&gt;&quot;These people ignore all the times that it moves inversely with sentiment,&quot; says
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oanda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Craig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  hell of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for cryptocurrency. Or, more specifically, cryptocurrency scams. That's according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chainalysis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a respected blockchain analysis company that works with law enforcement and … [+2253 chars]Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Welcome to another edition of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , where I,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , tell you whats been going on with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.

# %%
# List all Entities
for ent in bitcoin_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Bitcoin GPE
# $1.1 billion MONEY
# $57 million MONEY
# tens or hundreds of millions of dollars MONEY
# Bitcoin GPE
# Anchorage GPE
# +3802 chars]Shutterstock
# < WORK_OF_ART
# Bitcoin GPE
# bitcoin GPE
# Oanda PERSON
# Craig ORG
# 2019 DATE
# one CARDINAL
# a year DATE
# Chainalysis ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Satoshi Nakamoto PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Marie Curie PERSON
# +2657 WORK_OF_ART
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Pasteur PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Stephen Hawking PERSON
# Success ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Isaac Newton PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Marcus Aurelius PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Stephen Hawking PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Stephen Hawking PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Faraday DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Nikola Tesla ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Satoshi Nakamoto PERSON
# Intellig PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Jane Didion PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Machiavelli PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Nikola Tesla ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Descartes PERSON
# Lets PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Faraday DATE
# +2411 ORG

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
ethereum_text = ethereum_df.text.str.cat()
ethereum_text
# Out:
# "Not the city, the $57 million-funded cryptocurrency custodian startup. When someone wants to keep tens or hundreds of millions of dollars in Bitcoin, Ethereum, or other coins safe, they put them in Anchorage’s vault. And now they can trade straight from custo… [+3802 chars]Last week, I took out a loan without meeting anyone, signing anything, or even interacting with a human being.\xa0\r\nI also invested in a variety of assets that earn interest of up to 5.9 percent a year. I did it all on my own, from my computer. All I needed was … [+7841 chars]Blockchain has the two most popular and competitive platforms Multichain Vs. Ethereum. Blockchain has been a buzzword in the tech world. It also has more technical capabilities to offer in the global market. For business owners, investors, and even startups —… [+6386 chars]Bust out the champagne, folks! It's time to celebrate.\xa0\r\n2019 was one hell of a year for cryptocurrency. Or, more specifically, cryptocurrency scams. That's according to Chainalysis, a respected blockchain analysis company that works with law enforcement and … [+2253 chars]Virgil Griffith, the Ethereum developer arrested after allegedly traveling to North Korea to speak at a cryptocurrency conference, has been indicted.Court documents shared by CoinDesk show that Griffith is being charged with one count of conspiracy to violate… [+2544 chars]Theres more to cryptocurrency and blockchain than Bitcoin and Ethereum. There are many other competing coins and blockchain platforms, one of which is Cardano.\r\nCardano is an open-source blockchain and smart contracts platform, which is fueled by its namesake… [+5915 chars]The UK has opened a contract worth £100,000 ($130,000) to procure software to identify when cryptocurrency is used to avoid paying taxes.\r\nIn particular, HMRC is seeking the ability to cluster cryptocurrency transactions, identifying those linked to service p… [+1891 chars]Dfinity, a crypto-startup that caught headlines with its massive valuation even before launch, is showcasing an open social network called LinkedUp.\xa0\r\nLinkedUp is running on Dfinity's platform, which the company calls the Internet Computer. Instead of being h… [+2541 chars]Hello Hard Forkers, welcome to another Moonday Morning where we wrap-up the weekends hot cryptocurrency and blockchain headlines.\r\nTake a look.\r\n1. Illegal Bitcoin mine in Ukraine rail building busted\r\nA small but illegal Bitcoin mine has been located and dis… [+3282 chars]“We’re trying to shift cryptocurrency from this speculative asset class to driving real world utility” Coinbase CEO Brian Armstrong tells me. How? Through commerce and micropayments. But now Coinbase has the\xa0who to build it. Today the startup announces it’s h… [+3763 chars]Video forgery is becoming an epidemic. Blockchain technology can aid in the battle against malicious video alteration. A blockchain police bodycam is incorruptible. Here is building a blockchain police bodycam PoC for $25.\r\nPolice bodycams are essential for m… [+4740 chars]When Dfinity raised $102 million in funding in 2018 at a $2 billion valuation in a round jointly led by Andreessen Horowitz and Polychain Capital, it was thought of as a step change in the world of blockchain technology. In an area that was \xa0synonymous genera… [+5250 chars]The operator of New-York based company CabbageTech has been sentenced to 33 months in federal prison after pleading guilty to defrauding cryptocurrency investors in June last year.\r\nPatrick McDonnel, also known as Jason Flack, was also ordered to pay $224,352… [+1459 chars]The idea that blockchains may bring benefits in terms of cybersecurity is a widespread myth. Even the US Department of Defense fell for this myth in a recent report DoD Digital Modernization Strategy with plans to build a Block Chain Cybersecurity Shield allo… [+5523 chars]Tourists will have to have deep pockets to visit the final frontier of deep space as the trip costs a staggering $640,000 a nigh ...

# %%
# Run the NER processor on all of the text
ethereum_doc = nlp(ethereum_text)
# Add a title to the document
ethereum_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
# displacy.render(doc, style='ent', jupyter=True)
displacy.render(nlp(str(ethereum_doc)), style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Not the city, the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $57 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# -funded cryptocurrency custodian startup. When someone wants to keep
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tens or hundreds of millions of dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Ethereum, or other coins safe, they put them in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anchorage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s vault. And now they can trade straight from custo… [+3802
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]Last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>I also invested in a variety of assets that earn interest of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to 5.9 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  a year. I did it all on my own, from my computer. All I needed was … [+7841 chars]Blockchain has the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  most popular and competitive platforms Multichain Vs. Ethereum.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Blockchain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  hell of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for cryptocurrency. Or, more specifically, cryptocurrency scams. That's according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chainalysis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a respected blockchain analysis company that works with law enforcement and … [+2253 chars]Virgil
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Griffith
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the Ethereum developer arrested after allegedly traveling to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Korea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to speak at a cryptocurrency conference, has been indicted.Court documents shared by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CoinDesk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  show that
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Griffith
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is being charged with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  count of conspiracy to violate… [+2544 chars]Theres more to cryptocurrency and blockchain than
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . There are many other competing coins and blockchain platforms,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of which is
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cardano
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: midd

# %%
# List all Entities
for ent in ethereum_doc.ents:
    print(ent.text, ent.label_)
# Out:
# $57 million MONEY
# tens or hundreds of millions of dollars MONEY
# Bitcoin GPE
# Anchorage GPE
# chars]Last week DATE
# up to 5.9 percent PERCENT
# two CARDINAL
# Blockchain GPE
# 2019 DATE
# one CARDINAL
# a year DATE
# Chainalysis ORG
# Griffith PERSON
# North Korea GPE
# CoinDesk PERSON
# Griffith PERSON
# one CARDINAL
# Bitcoin GPE
# Ethereum GPE
# one CARDINAL
# Cardano GPE
# Cardano PERSON
# UK GPE
# 100,000 MONEY
# 130,000 MONEY
# HMRC ORG
# +1891 PRODUCT
# LinkedUp ORG
# Dfinity ORG
# Hard Forkers PERSON
# 1 CARDINAL
# Bitcoin GPE
# Ukraine GPE
# Bitcoin GPE
# Brian Armstrong PERSON
# Coinbase PERSON
# Today DATE
# Blockchain GPE
# PoC ORG
# 25 MONEY
# chars]When CARDINAL
# $102 million MONEY
# 2018 DATE
# $2 billion MONEY
# Andreessen Horowitz PERSON
# Polychain Capital ORG
# New-York GPE
# CabbageTech ORG
# 33 months DATE
# June last year DATE
# Patrick McDonnel PERSON
# Jason Flack PERSON
# 224,352 MONEY
# the US Department of Defense ORG
# DoD Digital Modernization Strategy ORG
# 640,000 MONEY
# NASA ORG
# first ORDINAL
# the International Space Station FAC
# enigma PRODUCT
# Bitcoin GPE
# 500 CARDINAL
# bitcoin GPE
# 1 CARDINAL
# the United Nations ORG
# North Korea GPE
# February DATE
# Reuters rep ORG
# Akon City GPE
# Twitter PERSON
# Senegal PERSON
# Bitcoin BTC Golds FAC
# 72,000 MONEY
# BTG ORG
# blockchain GPE
# between Thursday DATE
# $57 million MONEY
# tens or hundreds of millions of dollars MONEY
# Bitcoin GPE
# Anchorage GPE
# chars]Last week DATE
# up to 5.9 percent PERCENT
# two CARDINAL
# Blockchain GPE
# 2019 DATE
# one CARDINAL
# a year DATE
# Chainalysis ORG
# Griffith PERSON
# North Korea GPE
# CoinDesk PERSON
# Griffith PERSON
# one CARDINAL
# Bitcoin GPE
# Ethereum GPE
# one CARDINAL
# Cardano GPE
# Cardano PERSON
# UK GPE
# 100,000 MONEY
# 130,000 MONEY
# HMRC ORG
# +1891 PRODUCT
# LinkedUp ORG
# Dfinity ORG
# Hard Forkers PERSON
# 1 CARDINAL
# Bitcoin GPE
# Ukraine GPE
# Bitcoin GPE
# Brian Armstrong PERSON
# Coinbase PERSON
# Today DATE
# Blockchain GPE
# PoC ORG
# 25 MONEY
# chars]When CARDINAL
# $102 million MONEY
# 2018 DATE
# $2 billion MONEY
# Andreessen Horowitz PERSON
# Polychain Capital ORG
# New-York GPE
# CabbageTech ORG
# 33 months DATE
# June last year DATE
# Patrick McDonnel PERSON
# Jason Flack PERSON
# 224,352 MONEY
# the US Department of Defense ORG
# DoD Digital Modernization Strategy ORG
# 640,000 MONEY
# NASA ORG
# first ORDINAL
# the International Space Station FAC
# enigma PRODUCT
# Bitcoin GPE
# 500 CARDINAL
# bitcoin GPE
# 1 CARDINAL
# the United Nations ORG
# North Korea GPE
# February DATE
# Reuters rep ORG
# Akon City GPE
# Twitter PERSON
# Senegal PERSON
# Bitcoin BTC Golds FAC
# 72,000 MONEY
# BTG ORG
# blockchain GPE
# between Thursday DATE
# $57 million MONEY
# tens or hundreds of millions of dollars MONEY
# Bitcoin GPE
# Anchorage GPE
# chars]Last week DATE
# up to 5.9 percent PERCENT
# two CARDINAL
# Blockchain GPE
# 2019 DATE
# one CARDINAL
# a year DATE
# Chainalysis ORG
# Griffith PERSON
# North Korea GPE
# CoinDesk PERSON
# Griffith PERSON
# one CARDINAL
# Bitcoin GPE
# Ethereum GPE
# one CARDINAL
# Cardano GPE
# Cardano PERSON
# UK GPE
# 100,000 MONEY
# 130,000 MONEY
# HMRC ORG
# +1891 PRODUCT
# LinkedUp ORG
# Dfinity ORG
# Hard Forkers PERSON
# 1 CARDINAL
# Bitcoin GPE
# Ukraine GPE
# Bitcoin GPE
# Brian Armstrong PERSON
# Coinbase PERSON
# Today DATE
# Blockchain GPE
# PoC ORG
# 25 MONEY
# chars]When CARDINAL
# $102 million MONEY
# 2018 DATE
# $2 billion MONEY
# Andreessen Horowitz PERSON
# Polychain Capital ORG
# New-York GPE
# CabbageTech ORG
# 33 months DATE
# June last year DATE
# Patrick McDonnel PERSON
# Jason Flack PERSON
# 224,352 MONEY
# the US Department of Defense ORG
# DoD Digital Modernization Strategy ORG
# 640,000 MONEY
# NASA ORG
# first ORDINAL
# the International Space Station FAC
# enigma PRODUCT
# Bitcoin GPE
# 500 CARDINAL
# bitcoin GPE
# 1 CARDINAL
# the United Nations ORG
# North Korea GPE
# February DATE
# Reuters rep ORG
# Akon City GPE
# Twitter PERSON
# Senegal PERSON
# Bitcoin BTC Golds FAC
# 72,000 MONEY
# BTG ORG
# blockchain GPE
# between Thursday DATE
# $57 million MONEY
# tens or hundreds of millions of dollars MONEY
# Bitcoin GPE
# Anchorage GPE
# chars]Last week DATE
# up to 5.9 percent PERCENT
# two CARDINAL
# Blockchain GPE
# 2019 DATE
# one CARDINAL
# a year DATE
# Chainalysis ORG
# Griffith PERSON
# North Korea GPE
# CoinDesk PERSON
# Griffith PERSON
# one CARDINAL
# Bitcoin GPE
# Ethereum GPE
# one CARDINAL
# Cardano GPE
# Cardano PERSON
# UK GPE
# 100,000 MONEY
# 130,000 MONEY
# HMRC ORG
# +1891 PRODUCT
# LinkedUp ORG
# Dfinity ORG
# Hard Forkers PERSON
# 1 CARDINAL
# Bitcoin GPE
# Ukraine GPE
# Bitcoin GPE
# Brian Armstrong PERSON
# Coinbase PERSON
# Today DATE
# Blockchain GPE
# PoC ORG
# 25 MONEY
# chars]When CARDINAL
# $102 million MONEY
# 2018 DATE
# $2 billion MONEY
# Andreessen Horowitz PERSON
# Polychain Capital ORG
# New-York GPE
# CabbageTech ORG
# 33 months DATE
# June last year DATE
# Patrick McDonnel PERSON
# Jason Flack PERSON
# 224,352 MONEY
# the US Department of Defense ORG
# DoD Digital Modernization Strategy ORG
# 640,000 MONEY
# NASA ORG
# first ORDINAL
# the International Space Station FAC
# enigma PRODUCT
# Bitcoin GPE
# 500 CARDINAL
# bitcoin GPE
# 1 CARDINAL
# the United Nations ORG
# North Korea GPE
# February DATE
# Reuters rep ORG
# Akon City GPE
# Twitter PERSON
# Senegal PERSON
# Bitcoin BTC Golds FAC
# 72,000 MONEY
# BTG ORG
# blockchain GPE
# between Thursday DATE
